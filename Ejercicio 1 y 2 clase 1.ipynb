# %%
#Ejercicio 1: Variables y tipos de datos
nombres = input("Ingrese su nombre señor/señora:")
edades = input("cuántos años de edad tiene:")
print("Hola", nombres, "usted tiene", edades, "años")


#Ejercicio 2: Condicionales simples
numero_asignado = input("ingrese su numero:")
type(numero_asignado)
numero_asignado = int(numero_asignado) #acá tengo que redefinir el valor del numero asignado ya que este aparece como un string al venir de la variable input, ahora pasará a ser un entero
print(type(numero_asignado)) #ahora que reconvertí mi valor de un texto a un número, puedo aplicar el condicional para la tarea asignada

if numero_asignado > 1:
  print("su numero ingresado es positivo")
else:
    print("su numero ingresado es negativo")
# Out:
# Ingrese su nombre señor/señora:santiago
# cuántos años de edad tiene:22
# Hola santiago usted tiene 22 años
# ingrese su numero:3
# <class 'int'>
# su numero ingresado es positivo
